# %% [markdown]
# # Bilingual Generalization Experiment

# %%
import os
import sys
sys.path.append('../talk_tuner/')
from torch.utils.data import Dataset
from torch.utils.data.dataloader import DataLoader
import torch.nn.functional as F

from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
from tqdm.auto import tqdm

from collections import OrderedDict

from src.dataset import llama_v2_prompt

import numpy as np

import torch
from src.probes import LinearProbeClassification

from src.intervention_utils import return_classifier_dict



device = "cuda"
torch_device = "cuda"

# %% [markdown]
# ## Instantiate the model

# %%
access_token = ''

tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-13b-chat-hf", token=access_token, padding_side='left')
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-13b-chat-hf", token=access_token)
model.half().cuda();
model.eval();

# %% [markdown]
# ## Load the probe weights here

# %%
classifier_type = LinearProbeClassification
classifier_directory = "../probe_checkpoints/orig_controlling_probe"
return_user_msg_last_act = True
include_inst = True
layer_num = None
mix_scaler = False
residual_stream = True
logistic = True
sklearn = False

classifier_dict = return_classifier_dict(classifier_directory,
                                         classifier_type, 
                                         chosen_layer=layer_num,
                                         mix_scaler=mix_scaler,
                                         logistic=logistic,
                                         sklearn=sklearn,
                                        )

# %% [markdown]
# ## Hyperparameters

# %%
normalized=False
# Sampling hyperparameters
generation_temperature = 0
generation_top_p = 1

N = 8 # Intervention Strength

which_layers = [] # Which layer/s to intervene
from_idx = 20 # Hyperparameter
to_idx = 30 # Hyperparameter
residual = True # Set True
for name, module in model.named_modules():
    if residual and name!= "" and name[-1].isdigit():
        layer_num = name[name.rfind("model.layers.") + len("model.layers."):]
        if from_idx <= int(layer_num) < to_idx:
            which_layers.append(name)
    elif (not residual) and name.endswith(".mlp"):
        layer_num = name[name.rfind("model.layers.") + len("model.layers."):name.rfind(".mlp")]
        if from_idx <= int(layer_num) < to_idx:
            which_layers.append(name)
modified_layer_names = which_layers
        
attribute = "age" # which attribute to intervene

# %% [markdown]
# ## Batched Intervention code

# %% [markdown]
# From the TalkTuner codebase

# %%
from baukit import TraceDict
from torch import nn


if '<pad>' not in tokenizer.get_vocab():
    tokenizer.add_special_tokens({"pad_token":"<pad>"})

model.resize_token_embeddings(len(tokenizer))
model.config.pad_token_id = tokenizer.pad_token_id
assert model.config.pad_token_id == tokenizer.pad_token_id, "The model's pad token ID does not match the tokenizer's pad token ID!"

residual = True
def optimize_one_inter_rep(inter_rep, layer_name, target, probe,
                           N=4, normalized=False):
    global first_time
    tensor = (inter_rep.clone()).to(torch_device).requires_grad_(True)
    rep_f = lambda: tensor
    target_clone = target.clone().to(torch_device).to(torch.float)

    cur_input_tensor = rep_f().clone().detach()


    if normalized:
        cur_input_tensor = rep_f() + target_clone.view(1, -1) @ probe.proj[0].weight * N * 100 / rep_f().norm() 
    else:

        # print(f"rep_f().shape: {rep_f().shape}")
        # print(f"target_clone.view(1, -1).shape: {target_clone.view(1, -1).shape}")
        # print(f"N: {N}")
        # print(f"multiplication: {( target_clone.view(1, -1) @ probe.proj[0].weight ).shape}")

        cur_input_tensor = rep_f() + target_clone.view(1, -1) @ probe.proj[0].weight * N
    return cur_input_tensor.clone()


def edit_inter_rep_multi_layers(output, layer_name):
    if residual:
        layer_num = layer_name[layer_name.rfind("model.layers.") + len("model.layers."):]
    else:
        layer_num = layer_name[layer_name.rfind("model.layers.") + len("model.layers."):layer_name.rfind(".mlp")]
    layer_num = int(layer_num)
    probe = classifier_dict[attribute][layer_num + 1]
    print(f"output: {output.shape}")
    print(f"output[0][:,-1].shape: {output[:, -1, :].shape}")
    cloned_inter_rep = output[:, -1,:].detach().clone().to(torch.float)
    print(f"cloned_inter_rep: {cloned_inter_rep.shape}")
    with torch.enable_grad():
        cloned_inter_rep = optimize_one_inter_rep(cloned_inter_rep, layer_name, 
                                                  cf_target, probe,
                                                  N=N,
                                                  normalized=False)
    output[:,  -1,:] = cloned_inter_rep.to(torch.float16)
    return output


def collect_responses_batched(prompts, modified_layer_names, edit_function, batch_size=5, rand=None):
    print(modified_layer_names)
    responses = []
    for i in tqdm(range(0, len(prompts), batch_size)): 
        
        message_lists = [[{"role": "user", 
                         "content": prompt},
                        ] for prompt in prompts[i:i+batch_size]]

        # Transform the message list into a prompt string
        formatted_prompts = [llama_v2_prompt(message_list) for message_list in message_lists]
        
        with TraceDict(model, modified_layer_names, edit_output=edit_function) as ret:
            with torch.no_grad():
                inputs = tokenizer(formatted_prompts, return_tensors='pt', padding=True).to('cuda')
                tokens = model.generate(**inputs,
                                        max_new_tokens=768,
                                        do_sample=False,
                                        temperature=generation_temperature,
                                        top_p=generation_top_p,
                                       )
                
        output = [tokenizer.decode(seq, skip_special_tokens=True).split('[/INST]')[1] for seq in tokens]
        responses.extend(output)

    return responses

# %% [markdown]
# ## English Inference

# %%
cf_target = [0, 0, 0, 0]
# cf_target = [0, 0]

cf_target[3] = 1
cf_target = torch.Tensor([cf_target])

# and we want the strength to be 8
N = 8

# We want to modify layers 20 to 30
modified_layer_names = which_layers

batch_size = 2
# and we have an array of questions
questions = ["Can you suggest five fun outdoor activities for me?", 
             "How can I learn to use technology more efficiently?",]
results = collect_responses_batched(questions, modified_layer_names, edit_inter_rep_multi_layers, batch_size=batch_size, rand=None)
# Out:
# ['model.layers.20', 'model.layers.21', 'model.layers.22', 'model.layers.23', 'model.layers.24', 'model.layers.25', 'model.layers.26', 'model.layers.27', 'model.layers.28', 'model.layers.29']
#   0%|          | 0/1 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# output: torch.Size([2, 119, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 119, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 119, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 119, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 119, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 119, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 119, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 119, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 119, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 119, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# ...
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# 100%|██████████| 1/1 [00:18<00:00, 18.67s/it]
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([2, 5120])
# cloned_inter_rep: torch.Size([2, 5120])

# %%
for i in range(len(questions)):
    text = f"USER: {questions[i]}\n\n"
    text += "-" * 50 + "\n"
    text += f"Intervened:\n"
    text += f"CHATBOT: {results[i]}"
    text += "\n\n" + "-" * 50 + "\n"
    
    print(text)
# Out:
# USER: Can you suggest five fun outdoor activities for me?
#
# --------------------------------------------------
# Intervened:
# CHATBOT:   Of course! I'd be happy to help you find some fun outdoor activities. Here are five suggestions:
#
# 1. Hiking or walking: Take a leisurely walk or hike through a nearby park or nature reserve to enjoy the fresh air and scenery. You can choose a route that suits your fitness level and enjoy the peaceful surroundings.
# 2. Picnic: Pack a basket with your favorite food and drinks and enjoy a picnic in a park or by a body of water. You can also bring along a blanket and some comfortable cushions to make the experience even more enjoyable.
# 3. Cycling: Dust off your bicycle and take a leisurely ride through a scenic route. You can explore local parks or bike trails and enjoy the exercise and fresh air.
# 4. Birdwatching: Take a pair of binoculars and a notebook and go birdwatching in a nearby park or nature reserve. You can identify different species of birds and learn about their habits and habitats.
# 5. Gardening: If you have a garden or a balcony, you can enjoy gardening as an outdoor activity. Plant some flowers or vegetables and enjoy the process of nurturing them. You can also enjoy the fresh air and the sense of accomplishment as you watch your plants grow.
#
# I hope these suggestions help you find a fun outdoor activity that suits your interests and abilities. Remember to always prioritize safety and take necessary precautions to protect yourself from the elements and any potential hazards.
#
# --------------------------------------------------
#
# USER: How can I learn to use technology more efficiently?
#
# --------------------------------------------------
# Intervened:
# CHATBOT:   Learning to use technology more efficiently can be a valuable skill in today's digital age. Here are some tips that may help you improve your technology usage:
#
# 1. Start with the basics: Before diving into advanced features and tools, make sure you have a solid understanding of the basics. This includes understanding the basic functions of your devices, such as how to use a keyboard, mouse, and basic software applications.
# 2. Take advantage of tutorials and guides: There are many online resources available that can help you learn how to use technology more efficiently. Look for tutorials, guides, and videos that provide step-by-step instructions on how to use specific software and hardware.
# 3. Practice regularly: The more you use technology, the more comfortable you will become with it. Practice using different software and hardware on a regular basis to improve your skills.
# 4. Use keyboard shortcuts: Keyboard shortcuts can save you a lot of time and improve your productivity. Take the time to learn common keyboard shortcuts for tasks such as cutting, copying, and pasting.
# 5. Use software and apps that are designed to improve productivity: There are many software and apps available that are designed to help you work more efficiently. For example, you can use project management software to keep track of your tasks and deadlines, or use a password manager to keep your passwords organized.
# 6. Stay up-to-date with the latest technology: Keep your software and hardware up-to-date to ensure that you are using the latest features and security patches.
# 7. Use technology to automate repetitive tasks: Look for ways to automate repetitive tasks, such as using software to automatically back up your files or schedule appointments.
# 8. Use technology to improve your organization: Use technology to improve your organization and productivity, such as using a digital calendar to keep track of your appointments and deadlines.
# 9. Use technology to improve your communication: Use technology to improve your communication, such as using video conferencing software to communicate with colleagues or clients.
# 10. Take breaks: It's important to take breaks from technology to avoid burnout. Take regular breaks to rest your eyes, stretch, and relax.
#
# By following these tips, you can learn to use technology more efficiently and improve your productivity. Remember to always use technology in a safe and responsible manner, and to take breaks to avoid burnout.
#
# --------------------------------------------------

# %% [markdown]
# ## Spanish Inference

# %%
sys.path.append('../')
from translator import ConversationTranslator


spanish_questions = [ConversationTranslator('es').translate_text(question) for question in questions]
print(spanish_questions)
responses = []
for i in tqdm(range(0, len(spanish_questions), batch_size)): 
  
  message_lists = [[{"role": "user", 
                  "content": prompt},
                  ] for prompt in spanish_questions[i:i+batch_size]]

  # Transform the message list into a prompt string
  formatted_prompts = [llama_v2_prompt(message_list) for message_list in message_lists]
  
  with torch.no_grad():
      inputs = tokenizer(formatted_prompts, return_tensors='pt', padding=True).to('cuda')
      tokens = model.generate(**inputs,
                              max_new_tokens=768,
                              do_sample=False,
                              temperature=generation_temperature,
                              top_p=generation_top_p,
                            )
          
  output = [tokenizer.decode(seq, skip_special_tokens=True).split('[/INST]')[1] for seq in tokens]

  responses.extend(output)
# Out:
# ['¿Puedes sugerirme cinco actividades al aire libre divertidas?', '¿Cómo puedo aprender a usar la tecnología de manera más eficiente?']
#   0%|          | 0/1 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 100%|██████████| 1/1 [00:22<00:00, 22.46s/it]

# %%
for i in range(len(spanish_questions)):
    text = f"USER: {spanish_questions[i]}\n\n"
    text += "-" * 50 + "\n"
    text += f"Intervened:\n"
    text += f"CHATBOT: {responses[i]}"
    text += "\n\n" + "-" * 50 + "\n"
    
    print(text)
# Out:
# USER: ¿Puedes sugerirme cinco actividades al aire libre divertidas?
#
# --------------------------------------------------
# Intervened:
# CHATBOT:   ¡Por supuesto! Aquí te sugiero cinco actividades al aire libre divertidas y seguras:
#
# 1. Caminar o hacer senderismo: Elige un parque o un camino en la naturaleza y disfruta del aire fresco y la belleza del entorno. Puedes hacer un recorrido corto o largo, según tus preferencias y capacidad.
# 2. Practicar yoga al aire libre: Busca un lugar tranquilo y soleado, como un parque o una playa, y establece tu propio espacio de yoga. El aire libre te brindará una sensación de liberación y conexión con la naturaleza.
# 3. Hacer un picnic: Prepara un delicioso picnic con tus seres queridos en un parque o en un lugar tranquilo. Disfruta de la comida y la compañía en un entorno natural.
# 4. Realizar actividades creativas al aire libre: Si te gusta dibujar, pintar o hacer fotos, busca un lugar con buena luz natural y comienza a crear. El aire libre te inspirará y te permitirá experimentar tu creatividad de manera diferente.
# 5. Practicar deportes al aire libre: Elige un deporte que te guste, como el fútbol, el voleibol o el básquet, y busca un lugar abierto para jugar. El aire libre te permitirá moverte libremente y disfrutar del sol y el aire fresco.
#
# Recuerda siempre seguir las medidas de seguridad y precauciones adecuadas para realizar estas actividades al aire libre, como protegerse del sol y la humedad, hidratarse adecuadamente y evitar actividades que puedan ser peligrosas para tu salud. ¡Disfruta del tiempo libre al aire libre!
#
# --------------------------------------------------
#
# USER: ¿Cómo puedo aprender a usar la tecnología de manera más eficiente?
#
# --------------------------------------------------
# Intervened:
# CHATBOT:   ¡Hola! Me alegra que estés interesado en aprender a usar la tecnología de manera más eficiente. Aquí te presento algunas sugerencias que pueden ayudarte a lograrlo:
#
# 1. Identifica tus objetivos: Antes de empezar a aprender, debes tener claros tus objetivos y qué quieres lograr. ¿Quieres mejorar tus habilidades en un área específica de la tecnología? ¿O quieres aprender nuevas habilidades?
# 2. Planifica tu aprendizaje: Una vez que tengas claros tus objetivos, planifica tu aprendizaje. Establece metas y objetivos específicos, y divide tu aprendizaje en pasos pequeños y alcanzables.
# 3. Utiliza recursos de aprendizaje en línea: Hay muchos recursos en línea gratuitos o de pago que pueden ayudarte a aprender tecnologías nuevas. Puedes buscar cursos en plataformas como Coursera, Udemy, edX, o YouTube.
# 4. Practica lo aprendido: La práctica es esencial para mejorar tus habilidades en la tecnología. Practica lo aprendido en un entorno seguro y controlado.
# 5. Aprende de los errores: No te desanimes si te encuentras con errores. Aprender a depuración y a resolver problemas es una parte importante del proceso de aprendizaje.
# 6. Mantén tu conocimiento actualizado: La tecnología está en constante evolución, por lo que es importante mantener tu conocimiento actualizado. Investiga sobre las últimas tendencias y tecnologías emergentes en tu área de interés.
# 7. Busca la ayuda de la comunidad: La comunidad de desarrolladores y usuarios de tecnología es una fuente valiosa de conocimientos y recursos. Busca foros, grupos de LinkedIn o comunidades en línea para conectarte con otros que comparten tus intereses.
# 8. Usa herramientas de productividad: Utiliza herramientas de productividad como aplicaciones de gestión del tiempo, notas y lista de verificación para ayudarte a organizar tu aprendizaje y a mantenerte en el camino.
# 9. Aprende a utilizar herramientas de automatización: La automatización puede ayudarte a ahorrar tiempo y esfuerzo en tus tareas diarias. Aprende a utilizar herramientas como scripts de Python, PowerShell o IFTTT para automatizar tareas repetitivas.
# 10. Continúa aprendiendo: La tecnología es un campo amplio y en constante evolución, por lo que es importante que continúes aprendiendo y actualizando tus habilidades.
#
# Recuerda que aprender a utilizar la tecnología de manera más eficiente es un proceso continuo. Practica, experimenta y mantén tu conocimiento actualizado para mejorar tus habilidades en la tecnología. ¡Buena suerte!
#
# --------------------------------------------------

# %% [markdown]
# ## load the bilingual probe

# %%
classifier_type = LinearProbeClassification
classifier_directory = "../probe_checkpoints/bilingual_controlling_probe"
return_user_msg_last_act = True
include_inst = True
layer_num = None
mix_scaler = False
residual_stream = True
logistic = True
sklearn = False

classifier_dict = return_classifier_dict(classifier_directory,
                                         classifier_type, 
                                         chosen_layer=layer_num,
                                         mix_scaler=mix_scaler,
                                         logistic=logistic,
                                         sklearn=sklearn,
                                        )

# %%
normalized=False
# Sampling hyperparameters
generation_temperature = 0
generation_top_p = 1

N = 8 # Intervention Strength

which_layers = [] # Which layer/s to intervene
from_idx = 20 # Hyperparameter
to_idx = 30 # Hyperparameter
residual = True # Set True
for name, module in model.named_modules():
    if residual and name!= "" and name[-1].isdigit():
        layer_num = name[name.rfind("model.layers.") + len("model.layers."):]
        if from_idx <= int(layer_num) < to_idx:
            which_layers.append(name)
    elif (not residual) and name.endswith(".mlp"):
        layer_num = name[name.rfind("model.layers.") + len("model.layers."):name.rfind(".mlp")]
        if from_idx <= int(layer_num) < to_idx:
            which_layers.append(name)
modified_layer_names = which_layers
        
attribute = "age" # which attribute to intervene

# %%
from baukit import TraceDict
from torch import nn


if '<pad>' not in tokenizer.get_vocab():
    tokenizer.add_special_tokens({"pad_token":"<pad>"})

model.resize_token_embeddings(len(tokenizer))
model.config.pad_token_id = tokenizer.pad_token_id
assert model.config.pad_token_id == tokenizer.pad_token_id, "The model's pad token ID does not match the tokenizer's pad token ID!"

residual = True
def optimize_one_inter_rep(inter_rep, layer_name, target, probe,
                           N=4, normalized=False):
    global first_time
    tensor = (inter_rep.clone()).to(torch_device).requires_grad_(True)
    rep_f = lambda: tensor
    target_clone = target.clone().to(torch_device).to(torch.float)

    cur_input_tensor = rep_f().clone().detach()


    if normalized:
        cur_input_tensor = rep_f() + target_clone.view(1, -1) @ probe.proj[0].weight * N * 100 / rep_f().norm() 
    else:

        # print(f"rep_f().shape: {rep_f().shape}")
        # print(f"target_clone.view(1, -1).shape: {target_clone.view(1, -1).shape}")
        # print(f"N: {N}")
        # print(f"multiplication: {( target_clone.view(1, -1) @ probe.proj[0].weight ).shape}")

        cur_input_tensor = rep_f() + target_clone.view(1, -1) @ probe.proj[0].weight * N
    return cur_input_tensor.clone()


def edit_inter_rep_multi_layers(output, layer_name):
    if residual:
        layer_num = layer_name[layer_name.rfind("model.layers.") + len("model.layers."):]
    else:
        layer_num = layer_name[layer_name.rfind("model.layers.") + len("model.layers."):layer_name.rfind(".mlp")]
    layer_num = int(layer_num)
    probe = classifier_dict[attribute][layer_num + 1]
    print(f"output: {output.shape}")
    print(f"output[0][:,-1].shape: {output[0][:,-1].shape}")
    cloned_inter_rep = output[:, -1,:].unsqueeze(0).detach().clone().to(torch.float)
    print(f"cloned_inter_rep: {cloned_inter_rep.shape}")
    with torch.enable_grad():
        cloned_inter_rep = optimize_one_inter_rep(cloned_inter_rep, layer_name, 
                                                  cf_target, probe,
                                                  N=N,
                                                  normalized=False)
    output[:,  -1,:] = cloned_inter_rep.to(torch.float16)
    return output


def collect_responses_batched(prompts, modified_layer_names, edit_function, batch_size=5, rand=None):
    print(modified_layer_names)
    responses = []
    for i in tqdm(range(0, len(prompts), batch_size)): 
        
        message_lists = [[{"role": "user", 
                         "content": prompt},
                        ] for prompt in prompts[i:i+batch_size]]

        # Transform the message list into a prompt string
        formatted_prompts = [llama_v2_prompt(message_list) for message_list in message_lists]
        
        with TraceDict(model, modified_layer_names, edit_output=edit_function) as ret:
            with torch.no_grad():
                inputs = tokenizer(formatted_prompts, return_tensors='pt', padding=True).to('cuda')
                tokens = model.generate(**inputs,
                                        max_new_tokens=768,
                                        do_sample=False,
                                        temperature=generation_temperature,
                                        top_p=generation_top_p,
                                       )
                
        output = [tokenizer.decode(seq, skip_special_tokens=True).split('[/INST]')[1] for seq in tokens]
        responses.extend(output)

    return responses

# %%
cf_target = [0, 0, 0, 0]
# cf_target = [0, 0]

cf_target[0] = 1
cf_target = torch.Tensor([cf_target])

# and we want the strength to be 8
N = 8

# We want to modify layers 20 to 30
modified_layer_names = which_layers

batch_size = 2
# and we have an array of questions
questions = ["Can you give me some outfits suggestions? I am going to attend my friend's birthday party tonight", 
             "What birthday gifts should I bring to my friends?",]
results = collect_responses_batched(questions, modified_layer_names, edit_inter_rep_multi_layers, batch_size=batch_size, rand=None)
# Out:
# ['model.layers.20', 'model.layers.21', 'model.layers.22', 'model.layers.23', 'model.layers.24', 'model.layers.25', 'model.layers.26', 'model.layers.27', 'model.layers.28', 'model.layers.29']
#   0%|          | 0/1 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# output: torch.Size([2, 132, 5120])
# output[0][:,-1].shape: torch.Size([132])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 132, 5120])
# output[0][:,-1].shape: torch.Size([132])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 132, 5120])
# output[0][:,-1].shape: torch.Size([132])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 132, 5120])
# output[0][:,-1].shape: torch.Size([132])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 132, 5120])
# output[0][:,-1].shape: torch.Size([132])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 132, 5120])
# output[0][:,-1].shape: torch.Size([132])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 132, 5120])
# output[0][:,-1].shape: torch.Size([132])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 132, 5120])
# output[0][:,-1].shape: torch.Size([132])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 132, 5120])
# output[0][:,-1].shape: torch.Size([132])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 132, 5120])
# output[0][:,-1].shape: torch.Size([132])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# ...
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# 100%|██████████| 1/1 [00:11<00:00, 11.11s/it]
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])
# output: torch.Size([2, 1, 5120])
# output[0][:,-1].shape: torch.Size([1])
# cloned_inter_rep: torch.Size([1, 2, 5120])

# %%
for i in range(len(questions)):
    text = f"USER: {questions[i]}\n\n"
    text += "-" * 50 + "\n"
    text += f"Intervened:\n"
    text += f"CHATBOT: {results[i]}"
    text += "\n\n" + "-" * 50 + "\n"
    
    print(text)
# Out:
# USER: Can you give me some outfits suggestions? I am going to attend my friend's birthday party tonight
#
# --------------------------------------------------
# Intervened:
# CHATBOT:   Of course! I'd be happy to help you find some outfit ideas for your friend's birthday party tonight. Before I start suggesting outfits, can you tell me a bit more about the party? What is the theme, if any, and what is the dress code? Also, what is your personal style like? Do you like dressing up in fancy clothes or do you prefer something more casual and playful? Knowing these details will help me give you more tailored suggestions. 😊
#
# --------------------------------------------------
#
# USER: What birthday gifts should I bring to my friends?
#
# --------------------------------------------------
# Intervened:
# CHATBOT:   Hello! I'd be happy to help you find some birthday gift ideas for your friends! However, I want to point out that it's important to consider the individual interests and preferences of each friend, as well as any allergies or sensitivities they may have. It's also important to be mindful of the age and gender of the friend, as some gifts may not be appropriate for all ages or genders.
#
# Instead of suggesting specific gifts, I can offer some general ideas that might be suitable for most friends:
#
# 1. A fun and unique experience, like tickets to a concert or a local event, a fun activity like rock climbing or a scavenger hunt, or a special meal at a new restaurant.
# 2. A personalized item, like a customized mug or a photo album, that shows you put thought and effort into the gift.
# 3. A gift that supports their hobbies or interests, like a new book or a special piece of art supplies.
# 4. A fun and cozy item for their home, like a new throw blanket or a set of colorful dishes.
# 5. A gift that helps them relax and unwind, like a scented candle or a set of bath bombs.
#
# Remember, the most important thing is to show your friends that you care and that you're thinking of them on their special day. Whatever gift you choose, make sure it's something that brings them joy and makes them feel special!
#
# --------------------------------------------------

# %%
sys.path.append('../')
from translator import ConversationTranslator


questions = ["Can you give me some outfits suggestions? I am going to attend my friend's birthday party tonight.", 
             "What birthday gifts should I bring to my friends? ",]

spanish_questions = [ConversationTranslator('es').translate_text(question) for question in questions]
print(spanish_questions)
responses = []

for i in tqdm(range(0, len(spanish_questions), batch_size)): 
  
  message_lists = [[{"role": "user", 
                  "content": prompt},
                  ] for prompt in spanish_questions[i:i+batch_size]]

  # Transform the message list into a prompt string
  formatted_prompts = [llama_v2_prompt(message_list) for message_list in message_lists]
  
  with torch.no_grad():
      inputs = tokenizer(formatted_prompts, return_tensors='pt', padding=True).to('cuda')
      tokens = model.generate(**inputs,
                              max_new_tokens=768,
                              do_sample=False,
                              temperature=generation_temperature,
                              top_p=generation_top_p,
                            )
          
  output = [tokenizer.decode(seq, skip_special_tokens=True).split('[/INST]')[1] for seq in tokens]

  responses.extend(output)
# Out:
# ['¿Puedes darme algunas sugerencias de atuendos? Voy a asistir a la fiesta de cumpleaños de mi amigo esta noche.', '¿Qué regalos de cumpleaños debo traer a mis amigos?']
#   0%|          | 0/1 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 100%|██████████| 1/1 [00:22<00:00, 22.38s/it]

# %%
for i in range(len(spanish_questions)):
    text = f"USER: {spanish_questions[i]}\n\n"
    text += "-" * 50 + "\n"
    text += f"Intervened:\n"
    text += f"CHATBOT: {responses[i]}"
    text += "\n\n" + "-" * 50 + "\n"
    
    print(text)
# Out:
# USER: ¿Puedes darme algunas sugerencias de atuendos? Voy a asistir a la fiesta de cumpleaños de mi amigo esta noche.
#
# --------------------------------------------------
# Intervened:
# CHATBOT:   ¡Hola! ¡Claro que sí! Me encantaría ayudarte a elegir un atuendo adecuado para la fiesta de cumpleaños de tu amigo.
#
# Para empezar, es importante tener en cuenta el tema de la fiesta y el ambiente en el que se celebrará. ¿Sabes si es una fiesta formal o informal? ¿Se celebrará en una discoteca, un parque o en una casa? Esto ayudará a determinar el tipo de atuendo que debes elegir.
#
# Aquí te dejo algunas sugerencias de atuendos que podrían ser adecuados para una fiesta de cumpleaños:
#
# 1. Un traje y una camisa elegante: Un traje y una camisa limpios y bien planchados son un atuendo clásico y elegante que siempre funciona bien. Puedes elegir entre diferentes estilos de trajes, como un traje negro, gris o azul, y combinarlo con una camisa blanca o de un color pastel.
# 2. Un conjunto de pantalones y camisa: Un conjunto de pantalones y camisa es otro atuendo versátil y cómodo que se puede adaptar a diferentes entornos. Puedes elegir entre diferentes estilos de pantalones, como pantalones vaqueros, negros o de cuero, y combinarlos con una camisa de un color que complemente el color de los pantalones.
# 3. Una blusa y un par de shorts: Si la fiesta es más informal, una blusa y un par de shorts pueden ser un atuendo adecuado. Puedes elegir entre diferentes estilos de blusas, como una blusa de seda o una blusa de tirantes, y combinarla con un par de shorts de algodón o de cuero.
# 4. Un jersey y un par de pantalones deportivos: Si la fiesta es una fiesta al aire libre o una fiesta de deporte, un jersey y un par de pantalones deportivos pueden ser un atuendo adecuado. Puedes elegir entre diferentes estilos de jerseys, como un jersey de cuello redondo o un jersey de manga larga, y combinarlos con un par de pantalones deportivos de algodón o de cuero.
#
# Recuerda que, además del atuendo, también es importante tener en cuenta el calzado y el accesoorio que usarás. Un par de zapatos cómodos y una gorra o un pañuelo pueden ser los detalles que completen tu atuendo.
#
# Espero que estas sugerencias te ayuden a elegir un atuendo adecuado para la fiesta de cumpleaños de tu amigo. ¡Disfruta la fiesta!
#
# --------------------------------------------------
#
# USER: ¿Qué regalos de cumpleaños debo traer a mis amigos?
#
# --------------------------------------------------
# Intervened:
# CHATBOT:   ¡Hola! ¡Claro que sí! Si estás buscando ideas de regalos de cumpleaños para tus amigos, aquí te dejo algunas sugerencias que pueden ser útiles:
#
# 1. Un libro o una novela que te gustaría que lean.
# 2. Un objeto personalizado, como una tarjeta de visita o un cuadro con una fotografía especial de los dos.
# 3. Un kit de bienestar o un producto de cuidado personal que te gustaría que prueben.
# 4. Un objeto de decoración para su hogar o su lugar de trabajo que tenga un significado especial para la amistad.
# 5. Un experimento de degustación de comida o bebida que te gustaría que intenten.
# 6. Un ticket para un concierto o un evento en vivo que te gustaría que asistan juntos.
# 7. Un juego o una actividad en grupo que puedan disfrutar juntos.
# 8. Un regalo de viaje, como un bolsón de viaje o una mochila, para inspirarles a explorar nuevos lugares.
# 9. Un objeto de tecnología que te gustaría que prueben, como un nuevo dispositivo de audio o un reloj inteligente.
# 10. Un regalo de bondad, como una donación a una causa que te gustaría que apoyen.
#
# Recuerda que lo más importante es que el regalo sea thoughtful y personal, y que refleje la amistad y la relación que compartís. ¡Espero que estas ideas te ayuden a encontrar el regalo perfecto para tus amigos!
#
# --------------------------------------------------
